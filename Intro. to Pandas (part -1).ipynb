# %% [markdown]
# # Pandas (part - 1)

# %% [markdown]
# ## Pandas is primally used worj in tabular data

# %% [markdown]
# ## CSV stands for Comma Seperated Value Format(Like your Excle format)
#
# ## if we want to do any kind of analysis on csv data then we need to first of all bring that data inot python environment and for that we need have to read the data,that mean we have to fech everythinf in tabular data format file.

# %%
import pandas as pd

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %% [markdown]
# ## the way this your data is displayed above is a different way of storing a data apart from lists,Dictionary,tuples..and set. This way of storing the data is a pandas data frame
# ### A DataFrame is a another kind of Data Structure

# %%
df.iloc[7:13]
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 7      e         b           y         w       t    l               f
# 8      p         x           y         w       t    p               f
# 9      e         b           s         y       t    a               f
# 10     e         x           y         y       t    l               f
# 11     e         x           y         y       t    a               f
# 12     e         b           s         y       t    a               f
#
#    gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 7             c         b          n  ...                        s
# 8             c         n          p  ...                        s
# 9             c         b          g  ...                        s
# 10            c         b          g  ...                        s
# 11            c         b          n  ...                        s
# 12            c         b          w  ...                        s
#
#    stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 7                       w                      w         p          w
# 8                       w                      w         p          w
# 9                       w                      w         p          w
# 10                      w                      w         p          w
# 11                      w                      w         p          w
# 12                      w                      w         p          w
#
#    ring-number ring-type spore-print-color population habitat
# 7            o         p                 n          s       m
# 8            o         p                 k          v       g
# 9            o         p                 k          s       m
# 10           o         p                 n          n       g
# 11           o         p                 k          s       m
# 12           o         p                 n          s       g
#
# [6 rows x 23 columns]

# %%
type(df["cap-shape"])
# Out:
# pandas.core.series.Series
